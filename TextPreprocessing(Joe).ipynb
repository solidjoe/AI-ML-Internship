# %% [markdown]
# <a href="https://colab.research.google.com/github/solidjoe/AI-ML-Internship/blob/main/TextPreprocessing(Joe).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import string
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('omw-1.4', quiet=True)
# Out:
# True

# %%
text =  """In many traditions of thought, and in many quiet reflections of the human mind, people have asked a question that is both simple and endlessly deep: what does art point to, and why does it exist at all? When we stand before a painting, or when we listen to a piece of music, or when we read a poem that somehow touches the heart, we often feel—as if, perhaps, there is something more than just color, sound, or language there. It is not only paint on a canvas; it is not only notes arranged in time; it is not merely words, commas, pauses, and punctuation marks. Rather, it seems to suggest, gently and persistently, that behind the work there is a mind, a will, a creator.

And yet, when we say this, we must ask: why does art have this effect on us? Why do we see intention in it, meaning in it, and design in it? A random splash of paint can be ignored, but a careful brushstroke—placed here, and then there, and then again, slowly, deliberately—invites interpretation. The observer says, “Someone made this.” And in that simple statement there lies a philosophical intuition: that patterns, beauty, and coherence do not simply appear without cause. They point, subtly but insistently, toward a maker.

Now, of course, the conversation does not end there. Some might argue that art is only human expression, nothing more; it is merely the outcome of neurons firing, of culture evolving, of materials interacting. But even if that were so, the question returns again, almost stubbornly: why does the human mind itself seek meaning? Why do we, again and again, create symbols, stories, images, and sounds that reach beyond survival, beyond utility, beyond mere function? The existence of art, in this sense, raises a further question about the nature of the human person, and perhaps, quietly, about the nature of reality itself.

Consider a simple example: a sculpture carved from stone. At first glance it is just matter, weight, and form. Yet when the viewer sees the sculpture—its symmetry, its proportion, its deliberate shaping—the mind does not stop at the stone. Instead, it moves, almost automatically, to the sculptor. The work points beyond itself. The stone says, in a way that is both silent and eloquent: someone shaped me. And so the artwork becomes, not merely an object, but a sign.

Philosophers, theologians, and artists have long noticed this movement of thought. A painting points to a painter; a symphony points to a composer; a poem points to a poet. The artwork is not self-explanatory. It carries within it traces of intention—decisions about color, rhythm, line, emphasis, silence, and punctuation; commas and pauses; beginnings and endings; harmony and tension. These are not accidents. They are choices.

If this is true of human art, some thinkers have wondered whether the same logic might extend further. When we encounter beauty in the natural world—the structure of a leaf, the order of the stars, the rhythm of seasons—we sometimes react in a similar way. We sense pattern; we sense order; we sense something that appears meaningful. And so the mind, once again, asks: is there a creator behind this as well?

Of course, such questions are not easily answered. They lead to debates, to arguments, to long nights of reflection. Some will say yes, pointing to the coherence of the universe, the existence of beauty, the human hunger for meaning. Others will say no, insisting that chance and necessity are enough. Yet the question persists, lingering in philosophy, in theology, and even in art itself.

Indeed, many artists have deliberately explored this tension. A painting may suggest transcendence without naming it; a poem may hint at the divine without declaring it; a piece of music may evoke longing—an almost homesick feeling for something beyond the visible world. Listeners and viewers often respond to such works with silence, or with contemplation, or with a quiet question: what is this pointing toward?

And so art becomes, in a sense, a philosophical gesture. It does not force an answer, but it invites a question. Through color, sound, rhythm, metaphor, commas, pauses, and carefully placed punctuation, it nudges the mind outward: beyond the canvas, beyond the instrument, beyond the page. It suggests—though it does not prove—that meaning might have a source, that beauty might have an origin, that the human longing for truth and goodness might not be accidental.

In the end, perhaps art functions like a signpost. A signpost is not the destination; it merely points the way. Yet without it, the traveler might never even suspect that there is a road ahead. Similarly, art may not settle the question of God, but it keeps the question alive. It reminds us that behind every work there is a maker, behind every symbol there is a mind, and behind every act of creation there lies, perhaps, a deeper mystery.

And so the conversation continues: quietly, thoughtfully, and sometimes with hesitation. We look at the artwork; we see the brushstrokes, the shapes, the commas and semicolons, the rhythms and pauses. And then we look beyond it, asking—again, and again, and again—what does this point to, and who, or what, might stand behind it?"""

# %%
text2 = """Language is everywhere around us, and yet it is also strangely mysterious. We speak, we write, we pause; we add commas, semicolons, dashes, and periods; we repeat words like and, but, because, if, then, and therefore. At first glance, language might seem to be nothing more than a system of sounds and symbols—letters on a page, vibrations in the air, marks of punctuation scattered across sentences. And yet, when we stop, and when we listen carefully, language appears to do something far deeper than simply transmit information. It points, again and again, beyond itself.

Consider how language works. A word, by itself, is only a small sign: a sequence of sounds, or a cluster of letters. Yet when someone says “truth,” or “beauty,” or “justice,” the mind does not remain fixed on the sound alone. Instead, it moves immediately toward meaning. The word is not the thing itself; it is only a pointer. In this way, language always gestures outward, beyond the symbol, beyond the punctuation, beyond the sentence. A comma divides ideas; a question mark opens inquiry; an exclamation mark signals wonder or surprise—but none of these marks are the realities they refer to. They are signs, and signs always indicate something more.

Because of this, philosophers and theologians have often reflected on the remarkable nature of language. Why should sounds—mere vibrations of air—carry meaning at all? Why should the human mind be able to arrange words into patterns that express logic, emotion, poetry, and reflection? A sentence, after all, is not merely a collection of words separated by spaces and commas. It is an ordered structure: subjects, predicates, conjunctions, clauses; pauses, emphases, and rhythms. When someone speaks, there is intention behind the words, and the listener senses that intention almost immediately.

This intuition—that language points to a mind—is difficult to escape. When we hear a meaningful sentence, we do not assume it appeared randomly. We assume that someone formed it, someone arranged the words deliberately, someone intended to communicate. Even when the speaker is absent, the written text still carries that sense of authorship. A paragraph, filled with punctuation and stopwords—and, the, of, to, because, if, then—still reveals order and purpose. Language is never just noise; it is structured meaning.

From this observation, some thinkers have drawn a larger philosophical reflection. If language points toward a speaker, and if meaning points toward a mind, then the human capacity for language itself raises a deeper question: why do we possess this capacity at all? Why is the world intelligible enough to be described with words, categories, and grammar? Why does the universe allow us to speak about truth, beauty, goodness, existence, and even God?

The question becomes even more striking when we notice how language often reaches beyond the visible world. We speak about abstract realities—hope, justice, eternity, mercy—things that cannot be held in the hand or measured with a ruler. And yet we understand them. We form sentences about them; we debate them; we write entire books filled with commas, parentheses, and careful punctuation in order to explore them. Language seems designed not only for describing the world, but also for exploring meaning itself.

Because of this, many religious thinkers have suggested that language reflects something about the nature of reality. If human beings are capable of meaning, of communication, of reasoning through words and sentences, perhaps this capacity mirrors a deeper source. Just as a poem points to a poet, or a speech points to a speaker, language itself may point—quietly, indirectly—toward a divine Logos, a rational and communicative foundation of the world.

This idea does not prove anything in a strict mathematical sense. Language cannot force belief, and punctuation cannot settle theology. Yet the structure of language does raise a persistent question. Every sentence presupposes meaning; every conversation presupposes understanding; every text presupposes that ideas can be shared between minds. The entire system—words, grammar, commas, conjunctions, pauses—depends on the possibility of communication.

And so language becomes, in a sense, a philosophical signpost. It shows that the world is not silent chaos. Instead, it is a place where meaning can be expressed, discovered, and discussed. We ask questions; we form arguments; we write essays filled with and, but, therefore, however, perhaps. And in doing so, we reveal something remarkable: the universe is a place where meaning exists, and where minds can search for it.

Perhaps this is why discussions of God so often take place through language. We ask: Who created the world? Why does it exist? What is the source of truth, goodness, and beauty? These questions are expressed in sentences, framed by commas and question marks, shaped by grammar and vocabulary. Language becomes the medium through which the human mind reaches outward—toward ultimate explanations, toward ultimate causes, toward God.

In the end, language itself may function like a subtle hint. Words are not ultimate realities; they are signs. Yet the existence of meaningful signs suggests the presence of meaning, and the presence of meaning suggests the possibility of a source. When we speak, when we write, when we carefully place punctuation—comma after clause, period after sentence—we participate in a remarkable system that points beyond itself.

And so the mystery remains. Language allows us to ask questions about existence, about purpose, about God. It does not silence the questions; it gives them form. Through words, pauses, conjunctions, and punctuation marks, the human mind continues its search—wondering, reasoning, questioning—about whether the very possibility of meaning, and of language itself, might ultimately point toward the divine."""

# %%
#Single input
text_combined = text + "\n" + text2

#Removing Punctuations and Tokenisation
text_clean = re.sub(f"[{re.escape(string.punctuation)}]", "", text_combined)
tokens = nltk.word_tokenize(text_clean.lower())

#Stop word removal
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]

final_clean_text = " ".join(filtered_tokens)

print("Tokens after Punctuation & Stop Word Removal:\n", filtered_tokens[:10])
print(final_clean_text)
# Out:
# Tokens after Punctuation & Stop Word Removal:
#  ['many', 'traditions', 'thought', 'many', 'quiet', 'reflections', 'human', 'mind', 'people', 'asked']
# ...

# %%
#Lemmatization

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

stemmed_output = [stemmer.stem(word) for word in filtered_tokens]
lemmatized_output = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print(f"{'Original':<15} | {'Stemmed':<15} | {'Lemmatized'}")
print("-" * 45)
for i in range(15):
    print(f"{filtered_tokens[i]:<15} | {stemmed_output[i]:<15} | {lemmatized_output[i]}")
# Out:
# Original        | Stemmed         | Lemmatized
# ---------------------------------------------
# many            | mani            | many
# traditions      | tradit          | tradition
# thought         | thought         | thought
# many            | mani            | many
# quiet           | quiet           | quiet
# reflections     | reflect         | reflection
# human           | human           | human
# mind            | mind            | mind
# people          | peopl           | people
# asked           | ask             | asked
# question        | question        | question
# simple          | simpl           | simple
# endlessly       | endlessli       | endlessly
# deep            | deep            | deep
# art             | art             | art

# %%
print(final_clean_text)
# Out:
# many traditions thought many quiet reflections human mind people asked question simple endlessly deep art point exist stand painting listen piece music read poem somehow touches heart often feel—as perhaps something color sound language paint canvas notes arranged time merely words commas pauses punctuation marks rather seems suggest gently persistently behind work mind creator yet say must ask art effect us see intention meaning design random splash paint ignored careful brushstroke—placed slowly deliberately—invites interpretation observer says “ someone made ” simple statement lies philosophical intuition patterns beauty coherence simply appear without cause point subtly insistently toward maker course conversation end might argue art human expression nothing merely outcome neurons firing culture evolving materials interacting even question returns almost stubbornly human mind seek meaning create symbols stories images sounds reach beyond survival beyond utility beyond mere functi
# ...
